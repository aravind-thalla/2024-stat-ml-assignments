# %% [markdown]
# <a href="https://colab.research.google.com/github/aravind-thalla/2024-stat-ml-assignments/blob/main/STAT_ML_final_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Reading data

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
data=pd.read_csv('/content/sample_data/drug_consumption.data')
data.head()
# Out:
#    1  0.49788  0.48246  -0.05921  0.96082  0.12600  0.31287  -0.57545  \
# 0  2 -0.07854 -0.48246   1.98437  0.96082 -0.31685 -0.67825   1.93886
# 1  3  0.49788 -0.48246  -0.05921  0.96082 -0.31685 -0.46725   0.80523
# 2  4 -0.95197  0.48246   1.16365  0.96082 -0.31685 -0.14882  -0.80615
# 3  5  0.49788  0.48246   1.98437  0.96082 -0.31685  0.73545  -1.63340
# 4  6  2.59171  0.48246  -1.22751  0.24923 -0.31685 -0.67825  -0.30033
#
#    -0.58331  -0.91699  ...  CL0.4  CL0.5  CL0.6 CL0.7 CL0.8 CL0.9 CL0.10  \
# 0   1.43533   0.76096  ...    CL4    CL0    CL2   CL0   CL2   CL3    CL0
# 1  -0.84732  -1.62090  ...    CL0    CL0    CL0   CL0   CL0   CL0    CL1
# 2  -0.01928   0.59042  ...    CL0    CL0    CL2   CL0   CL0   CL0    CL0
# 3  -0.45174  -0.30172  ...    CL1    CL0    CL0   CL1   CL0   CL0    CL2
# 4  -1.55521   2.03972  ...    CL0    CL0    CL0   CL0   CL0   CL0    CL0
#
#   CL2.2 CL0.11 CL0.12
# 0   CL4    CL0    CL0
# 1   CL0    CL0    CL0
# 2   CL2    CL0    CL0
# ...

# %%
target = data.iloc[:, 3]
target.head()
# Out:
# 0    1.98437
# 1   -0.05921
# 2    1.16365
# 3    1.98437
# 4   -1.22751
# Name: -0.05921, dtype: float64

# %%
x = data.drop(data.columns[:3], axis=1)
x.head()
# Out:
#    -0.05921  0.96082  0.12600  0.31287  -0.57545  -0.58331  -0.91699  \
# 0   1.98437  0.96082 -0.31685 -0.67825   1.93886   1.43533   0.76096
# 1  -0.05921  0.96082 -0.31685 -0.46725   0.80523  -0.84732  -1.62090
# 2   1.16365  0.96082 -0.31685 -0.14882  -0.80615  -0.01928   0.59042
# 3   1.98437  0.96082 -0.31685  0.73545  -1.63340  -0.45174  -0.30172
# 4  -1.22751  0.24923 -0.31685 -0.67825  -0.30033  -1.55521   2.03972
#
#    -0.00665  -0.21712  -1.18084  ... CL0.4 CL0.5 CL0.6 CL0.7 CL0.8 CL0.9  \
# 0  -0.14277  -0.71126  -0.21575  ...   CL4   CL0   CL2   CL0   CL2   CL3
# 1  -1.01450  -1.37983   0.40148  ...   CL0   CL0   CL0   CL0   CL0   CL0
# 2   0.58489  -1.37983  -1.18084  ...   CL0   CL0   CL2   CL0   CL0   CL0
# 3   1.30612  -0.21712  -0.21575  ...   CL1   CL0   CL0   CL1   CL0   CL0
# 4   1.63088  -1.37983  -1.54858  ...   CL0   CL0   CL0   CL0   CL0   CL0
#
#   CL0.10 CL2.2 CL0.11 CL0.12
# 0    CL0   CL4    CL0    CL0
# 1    CL1   CL0    CL0    CL0
# ...

# %%
x.isnull().sum()
# Out:
# -0.05921    0
# 0.96082     0
# 0.12600     0
# 0.31287     0
# -0.57545    0
# -0.58331    0
# -0.91699    0
# -0.00665    0
# -0.21712    0
# -1.18084    0
# CL5         0
# CL2         0
# CL0         0
# CL2.1       0
# CL6         0
# CL0.1       0
# CL5.1       0
# CL0.2       0
# CL0.3       0
# CL0.4       0
# CL0.5       0
# CL0.6       0
# CL0.7       0
# CL0.8       0
# CL0.9       0
# CL0.10      0
# CL2.2       0
# CL0.11      0
# CL0.12      0
# dtype: int64

# %%
x.replace('?',0, inplace=True)
x.isnull().sum()
# Out:
# -0.05921    0
# 0.96082     0
# 0.12600     0
# 0.31287     0
# -0.57545    0
# -0.58331    0
# -0.91699    0
# -0.00665    0
# -0.21712    0
# -1.18084    0
# CL5         0
# CL2         0
# CL0         0
# CL2.1       0
# CL6         0
# CL0.1       0
# CL5.1       0
# CL0.2       0
# CL0.3       0
# CL0.4       0
# CL0.5       0
# CL0.6       0
# CL0.7       0
# CL0.8       0
# CL0.9       0
# CL0.10      0
# CL2.2       0
# CL0.11      0
# CL0.12      0
# dtype: int64

# %%
target.replace('True',1, inplace=True)
target.replace('False',0, inplace=True)

# %% [markdown]
# #Before resampling data

# %%
x.dtypes
# Out:
# -0.05921    float64
# 0.96082     float64
# 0.12600     float64
# 0.31287     float64
# -0.57545    float64
# -0.58331    float64
# -0.91699    float64
# -0.00665    float64
# -0.21712    float64
# -1.18084    float64
# CL5          object
# CL2          object
# CL0          object
# CL2.1        object
# CL6          object
# CL0.1        object
# CL5.1        object
# CL0.2        object
# CL0.3        object
# CL0.4        object
# CL0.5        object
# CL0.6        object
# CL0.7        object
# CL0.8        object
# CL0.9        object
# CL0.10       object
# CL2.2        object
# CL0.11       object
# CL0.12       object
# dtype: object

# %%
print(x)
# Out:
#       -0.05921  0.96082  0.12600  0.31287  -0.57545  -0.58331  -0.91699  \
# 0      1.98437  0.96082 -0.31685 -0.67825   1.93886   1.43533   0.76096
# 1     -0.05921  0.96082 -0.31685 -0.46725   0.80523  -0.84732  -1.62090
# 2      1.16365  0.96082 -0.31685 -0.14882  -0.80615  -0.01928   0.59042
# 3      1.98437  0.96082 -0.31685  0.73545  -1.63340  -0.45174  -0.30172
# 4     -1.22751  0.24923 -0.31685 -0.67825  -0.30033  -1.55521   2.03972
# ...        ...      ...      ...      ...       ...       ...       ...
# 1879  -0.61113 -0.57009 -0.31685 -1.19430   1.74091   1.88511   0.76096
# 1880  -0.61113 -0.57009 -0.31685 -0.24649   1.74091   0.58331   0.76096
# 1881   0.45468 -0.57009 -0.31685  1.13281  -1.37639  -1.27553  -1.77200
# 1882  -0.61113 -0.57009 -0.31685  0.91093  -1.92173   0.29338  -1.62090
# 1883  -0.61113  0.21128 -0.31685 -0.46725   2.12700   1.65653   1.11406
#
#       -0.00665  -0.21712  -1.18084  ... CL0.4 CL0.5 CL0.6 CL0.7 CL0.8 CL0.9  \
# ...

# %%
for col in x.columns:
  if x[col].dtype == 'object':
    for col in x.columns:
      if x[col].dtype == 'object':
        try:
          x[col] = x[col].astype('int64')
        except ValueError:
          pass

# %%
print(x)
# Out:
#         cmp_fname_c1  cmp_fname_c2  cmp_lname_c1  cmp_lname_c2  cmp_sex  \
# 0                  0             0      1.000000             0        1
# 1                  1             0      1.000000             0        1
# 2                  1             0      1.000000             0        1
# 3                  1             0      1.000000             0        1
# 4                  1             0      1.000000             1        1
# ...              ...           ...           ...           ...      ...
# 574908             1             0      0.285714             0        1
# 574909             1             0      0.125000             0        1
# 574910             1             0      0.090909             0        1
# 574911             1             0      0.111111             0        1
# 574912             1             0      0.000000             0        1
#
#         cmp_bd  cmp_bm  cmp_by  cmp_plz
# 0            1       1       1        0
# ...

# %%
x.dtypes
# Out:
# -0.05921    float64
# 0.96082     float64
# 0.12600     float64
# 0.31287     float64
# -0.57545    float64
# -0.58331    float64
# -0.91699    float64
# -0.00665    float64
# -0.21712    float64
# -1.18084    float64
# CL5          object
# CL2          object
# CL0          object
# CL2.1        object
# CL6          object
# CL0.1        object
# CL5.1        object
# CL0.2        object
# CL0.3        object
# CL0.4        object
# CL0.5        object
# CL0.6        object
# CL0.7        object
# CL0.8        object
# CL0.9        object
# CL0.10       object
# CL2.2        object
# CL0.11       object
# CL0.12       object
# dtype: object

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1884 entries, 0 to 1883
# Data columns (total 29 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   -0.05921  1884 non-null   float64
#  1   0.96082   1884 non-null   float64
#  2   0.12600   1884 non-null   float64
#  3   0.31287   1884 non-null   float64
#  4   -0.57545  1884 non-null   float64
#  5   -0.58331  1884 non-null   float64
#  6   -0.91699  1884 non-null   float64
#  7   -0.00665  1884 non-null   float64
#  8   -0.21712  1884 non-null   float64
#  9   -1.18084  1884 non-null   float64
#  10  CL5       1884 non-null   object
#  11  CL2       1884 non-null   object
#  12  CL0       1884 non-null   object
#  13  CL2.1     1884 non-null   object
#  14  CL6       1884 non-null   object
#  15  CL0.1     1884 non-null   object
#  16  CL5.1     1884 non-null   object
#  17  CL0.2     1884 non-null   object
#  18  CL0.3     1884 non-null   object
# ...

# %%
x.describe()
# Out:
#           -0.05921      0.96082      0.12600      0.31287     -0.57545  \
# count  1884.000000  1884.000000  1884.000000  1884.000000  1884.000000
# mean     -0.003777     0.355221    -0.309808    -0.000119     0.000143
# std       0.950330     0.700382     0.165967     0.998345     0.997625
# min      -2.435910    -0.570090    -1.107020    -3.464360    -3.273930
# 25%      -0.611130    -0.570090    -0.316850    -0.678250    -0.695090
# 50%      -0.059210     0.960820    -0.316850     0.042570     0.003320
# 75%       0.454680     0.960820    -0.316850     0.629670     0.637790
# max       1.984370     0.960820     1.907250     3.273930     3.273930
#
#           -0.58331     -0.91699     -0.00665     -0.21712     -1.18084
# count  1884.000000  1884.000000  1884.000000  1884.000000  1884.000000
# mean     -0.000225     0.000242    -0.000383     0.007335    -0.002667
# std       0.996402     0.997481     0.997787     0.954674     0.963575
# ...

# %%
for clo in x.columns:
  print(x[clo].describe())
  print()
  print()
  print()
# Out:
# count    1884.000000
# mean       -0.003777
# std         0.950330
# min        -2.435910
# 25%        -0.611130
# 50%        -0.059210
# 75%         0.454680
# max         1.984370
# Name: -0.05921, dtype: float64
#
#
#
# count    1884.000000
# mean        0.355221
# std         0.700382
# min        -0.570090
# 25%        -0.570090
# 50%         0.960820
# 75%         0.960820
# max         0.960820
# Name: 0.96082, dtype: float64
#
#
#
# count    1884.000000
# mean       -0.309808
# std         0.165967
# min        -1.107020
# 25%        -0.316850
# 50%        -0.316850
# 75%        -0.316850
# max         1.907250
# Name: 0.12600, dtype: float64
#
#
#
# count    1884.000000
# mean       -0.000119
# std         0.998345
# min        -3.464360
# 25%        -0.678250
# 50%         0.042570
# 75%         0.629670
# max         3.273930
# Name: 0.31287, dtype: float64
#
#
#
# count    1884.000000
# mean        0.000143
# std         0.997625
# min        -3.273930
# ...

# %%
for clo in x.columns:
  print(x[clo].info())
  print()
  print()
  print()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 1884 entries, 0 to 1883
# Series name: -0.05921
# Non-Null Count  Dtype
# --------------  -----
# 1884 non-null   float64
# dtypes: float64(1)
# memory usage: 14.8 KB
# None
#
#
#
# <class 'pandas.core.series.Series'>
# RangeIndex: 1884 entries, 0 to 1883
# Series name: 0.96082
# Non-Null Count  Dtype
# --------------  -----
# 1884 non-null   float64
# dtypes: float64(1)
# memory usage: 14.8 KB
# None
#
#
#
# <class 'pandas.core.series.Series'>
# RangeIndex: 1884 entries, 0 to 1883
# Series name: 0.12600
# Non-Null Count  Dtype
# --------------  -----
# 1884 non-null   float64
# dtypes: float64(1)
# memory usage: 14.8 KB
# None
#
#
#
# <class 'pandas.core.series.Series'>
# RangeIndex: 1884 entries, 0 to 1883
# Series name: 0.31287
# Non-Null Count  Dtype
# --------------  -----
# 1884 non-null   float64
# dtypes: float64(1)
# memory usage: 14.8 KB
# None
#
#
#
# <class 'pandas.core.series.Series'>
# ...

# %%
for clo in x.columns:
  print(x[clo].value_counts())
  print()
  print()
  print()
# Out:
# -0.05921
# -0.61113    506
#  0.45468    480
#  1.16365    283
# -0.05921    269
# -1.22751    100
# -1.73790     99
#  1.98437     89
# -1.43719     30
# -2.43591     28
# Name: count, dtype: int64
#
#
#
# 0.96082
#  0.96082    1043
# -0.57009     557
# -0.28519     118
#  0.24923      87
# -0.09765      54
#  0.21128      20
# -0.46841       5
# Name: count, dtype: int64
#
#
#
# 0.12600
# -0.31685    1720
#  0.11440      63
# -1.10702      33
# -0.50212      26
# -0.22166      20
#  0.12600      19
#  1.90725       3
# Name: count, dtype: int64
#
#
#
# 0.31287
# -0.46725    87
#  0.41667    80
# -0.34799    78
#  0.62967    77
# -0.14882    76
#  0.04257    73
# -0.79151    70
# -0.05188    69
# -0.24649    68
#  0.13606    67
#  1.02119    67
# -0.92104    65
#  0.31287    65
#  0.22393    63
# -0.58016    61
#  0.52135    61
# -0.67825    60
# -1.05308    57
# -1.19430    56
#  0.82562    51
#  1.23461    49
#  0.73545    49
#  1.37297    40
#  0.91093    37
# -1.32828    35
# ...

# %%
for clo in x.columns:
  print(x[clo].unique())
  print()
  print()
  print()
# Out:
# [ 1.98437 -0.05921  1.16365 -1.22751 -1.7379   0.45468 -0.61113 -2.43591
#  -1.43719]
#
#
#
# [ 0.96082  0.24923 -0.57009 -0.28519 -0.09765  0.21128 -0.46841]
#
#
#
# [-0.31685  0.1144  -0.22166 -0.50212  0.126   -1.10702  1.90725]
#
#
#
# [-0.67825 -0.46725 -0.14882  0.73545 -1.32828  0.62967 -0.24649 -1.05308
#   2.28554 -0.79151 -0.92104 -2.05048 -1.55078  0.52135  1.37297 -0.34799
#  -1.1943   0.41667  1.60383 -0.05188  0.04257  0.31287  1.02119  0.82562
#   0.13606  1.13281 -1.43907 -0.58016  0.22393 -2.21844  0.91093 -2.3436
#   1.8399   1.49158  3.27393 -1.69163  1.98437  2.82196  1.23461 -1.86962
#   2.127   -2.42317  2.46262  1.72012  2.61139 -2.75696 -2.52197 -3.15735
#  -3.46436]
#
#
#
# [ 1.93886  0.80523 -0.80615 -1.6334  -0.30033 -1.09207  2.57309  0.00332
#   0.16767  1.45421 -1.50796 -1.23177 -0.15487 -1.7625   0.47617 -0.94779
#  -3.27393  0.63779 -0.43999  1.74091 -0.57545  0.32197  1.2861   0.96248
# ...

# %%
for clo in x.columns:
  if x[clo].dtype == 'int64':
    sns.histplot(x[clo], discrete=True)
  elif x[clo].dtype == 'float64':
    sns.histplot(x[clo])

  plt.show()

# %%
for col in x.columns:
    sns.countplot(x=col, data=x)
    plt.show()

# %%
for col in x.columns:
    sns.scatterplot(x=x[col],y=target)
    plt.show()

# %%
x.corr(numeric_only=True)
# Out:
#           -0.05921   0.96082   0.12600   0.31287  -0.57545  -0.58331  \
# -0.05921  1.000000  0.225382 -0.036083 -0.100986  0.115638  0.057981
# 0.96082   0.225382  1.000000 -0.129410 -0.136366  0.109820 -0.341799
# 0.12600  -0.036083 -0.129410  1.000000  0.047293  0.019242  0.085795
# 0.31287  -0.100986 -0.136366  0.047293  1.000000 -0.431004  0.010275
# -0.57545  0.115638  0.109820  0.019242 -0.431004  1.000000  0.245142
# -0.58331  0.057981 -0.341799  0.085795  0.010275  0.245142  1.000000
# -0.91699  0.091080  0.151407 -0.037524 -0.216865  0.157103  0.038242
# -0.00665  0.240417  0.214045 -0.029969 -0.391098  0.308049 -0.056818
# -0.21712 -0.132491 -0.231513  0.082891  0.174445  0.114091  0.277468
# -1.18084 -0.131236 -0.345059  0.102231  0.080225  0.209858  0.421535
#
#           -0.91699  -0.00665  -0.21712  -1.18084
# -0.05921  0.091080  0.240417 -0.132491 -0.131236
# 0.96082   0.151407  0.214045 -0.231513 -0.345059
# 0.12600  -0.037524 -0.029969  0.082891  0.102231
# ...

# %%
numeric_x = x.select_dtypes(include=['number']) # This line creates numeric_x

plt.figure(figsize=(12, 10))
sns.heatmap(numeric_x.corr(), annot=True, cmap='coolwarm')
plt.show()

# %%
target.value_counts()
# Out:
# -0.05921
# -0.61113    506
#  0.45468    480
#  1.16365    283
# -0.05921    269
# -1.22751    100
# -1.73790     99
#  1.98437     89
# -1.43719     30
# -2.43591     28
# Name: count, dtype: int64

# %%
target.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 1884 entries, 0 to 1883
# Series name: -0.05921
# Non-Null Count  Dtype
# --------------  -----
# 1884 non-null   float64
# dtypes: float64(1)
# memory usage: 14.8 KB

# %%
target.describe()
# Out:
# count    1884.000000
# mean       -0.003777
# std         0.950330
# min        -2.435910
# 25%        -0.611130
# 50%        -0.059210
# 75%         0.454680
# max         1.984370
# Name: -0.05921, dtype: float64

# %% [markdown]
# #After resampling the data

# %%
import pandas as pd
from imblearn.over_sampling import SMOTE
from sklearn.preprocessing import LabelEncoder
string_cols = x.select_dtypes(include=['object']).columns
for col in string_cols:
    le = LabelEncoder()
    x[col] = le.fit_transform(x[col])
target_bins = pd.qcut(target, q=5, labels=False, duplicates='drop')
smote = SMOTE()
X, Y = smote.fit_resample(x, target_bins)

# %%
for clo in X.columns:
  print(X[clo].describe())
  print()
  print()
  print()
# Out:
# count    2289.000000
# mean        0.230689
# std         1.010767
# min        -2.435910
# 25%        -0.611130
# 50%         0.454680
# 75%         1.163650
# max         1.984370
# Name: -0.05921, dtype: float64
#
#
#
# count    2289.000000
# mean        0.407839
# std         0.684678
# min        -0.570090
# 25%        -0.570090
# 50%         0.960820
# 75%         0.960820
# max         0.960820
# Name: 0.96082, dtype: float64
#
#
#
# count    2289.000000
# mean       -0.310810
# std         0.157624
# min        -1.107020
# 25%        -0.316850
# 50%        -0.316850
# 75%        -0.316850
# max         1.907250
# Name: 0.12600, dtype: float64
#
#
#
# count    2289.000000
# mean       -0.034512
# std         0.969526
# min        -3.464360
# 25%        -0.678250
# 50%        -0.051880
# 75%         0.629670
# max         3.273930
# Name: 0.31287, dtype: float64
#
#
#
# count    2289.000000
# mean        0.036830
# std         0.967003
# min        -3.273930
# ...

# %%
for clo in X.columns:
  print(X[clo].info())
  print()
  print()
  print()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 2289 entries, 0 to 2288
# Series name: -0.05921
# Non-Null Count  Dtype
# --------------  -----
# 2289 non-null   float64
# dtypes: float64(1)
# memory usage: 18.0 KB
# None
#
#
#
# <class 'pandas.core.series.Series'>
# RangeIndex: 2289 entries, 0 to 2288
# Series name: 0.96082
# Non-Null Count  Dtype
# --------------  -----
# 2289 non-null   float64
# dtypes: float64(1)
# memory usage: 18.0 KB
# None
#
#
#
# <class 'pandas.core.series.Series'>
# RangeIndex: 2289 entries, 0 to 2288
# Series name: 0.12600
# Non-Null Count  Dtype
# --------------  -----
# 2289 non-null   float64
# dtypes: float64(1)
# memory usage: 18.0 KB
# None
#
#
#
# <class 'pandas.core.series.Series'>
# RangeIndex: 2289 entries, 0 to 2288
# Series name: 0.31287
# Non-Null Count  Dtype
# --------------  -----
# 2289 non-null   float64
# dtypes: float64(1)
# memory usage: 18.0 KB
# None
#
#
#
# <class 'pandas.core.series.Series'>
# ...

# %%
for clo in X.columns:
  print(X[clo].value_counts())
  print()
  print()
  print()
# Out:
# -0.05921
#  1.163650    525
# -0.611130    506
#  0.454680    487
# -0.059210    270
#  1.984370    122
#             ...
#  1.589776      1
#  1.644631      1
#  1.201501      1
#  1.708008      1
#  1.851621      1
# Name: count, Length: 131, dtype: int64
#
#
#
# 0.96082
#  0.960820    1324
# -0.570090     591
# -0.285190     122
#  0.249230      87
# -0.097650      54
#              ...
# -0.125885       1
#  0.709786       1
#  0.811630       1
#  0.115777       1
# -0.424289       1
# Name: count, Length: 92, dtype: int64
#
#
#
# 0.12600
# -0.316850    2045
#  0.114400      63
# -1.107020      33
# -0.502120      26
# -0.221660      20
#              ...
# -0.486475       1
# -0.500170       1
# -0.709326       1
# -0.305451       1
#  0.073329       1
# Name: count, Length: 87, dtype: int64
#
#
#
# 0.31287
# -0.467250    93
#  0.416670    81
# -0.347990    78
# -0.148820    77
#  0.629670    77
#              ..
# -1.787763     1
#  0.328026     1
# -0.250982     1
# ...

# %%
for clo in X.columns:
  print(X[clo].unique())
  print()
  print()
  print()
# Out:
# [ 1.98437    -0.05921     1.16365    -1.22751    -1.7379      0.45468
#  -0.61113    -2.43591    -1.43719    -0.01910357 -0.00321179  0.02494088
#   0.27642277  0.38231644  0.16414077  1.46208743  1.69149268  1.45856999
#   1.55698497  1.8550758   1.54275172  1.73728965  1.37144826  1.84912113
#   1.71859884  1.26709184  1.95049218  1.21806098  1.84188055  1.89899437
#   1.44342332  1.61495318  1.88876276  1.35461901  1.65667901  1.94460005
#   1.33620526  1.42359468  1.2249826   1.16895605  1.70800767  1.20150139
#   1.64463149  1.58977582  1.45562564  1.57256293  1.81795254  1.27630944
#   1.8860873   1.22235112  1.41185886  1.52173328  1.5170629   1.41448566
#   1.91506338  1.58416818  1.40720271  1.80235561  1.43589859  1.86785466
#   1.83621238  1.36367291  1.84710485  1.38975852  1.46034595  1.90460501
#   1.78098893  1.89433364  1.7804468   1.17085876  1.90063175  1.64633303
#   1.85819172  1.75571705  1.64525111  1.96246495  1.23340223  1.16719874
# ...

# %%
for clo in X.columns:
  if X[clo].dtype == 'int64':
    sns.histplot(X[clo], discrete=True)
  elif X[clo].dtype == 'float64':
    sns.histplot(X[clo])

  plt.show()

# %%
for col in X.columns:
    sns.countplot(x=col, data=X)
    plt.show()

# %%
for col in X.columns:
    sns.scatterplot(x=X[col],y=Y)
    plt.show()

# %%
plt.figure(figsize=(12, 10))
sns.heatmap(X.corr(), annot=True, cmap='coolwarm')
plt.show()

# %%
Y.value_counts()
# Out:
# -0.05921
# 2    763
# 1    763
# 0    763
# Name: count, dtype: int64

# %%
Y.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 2289 entries, 0 to 2288
# Series name: -0.05921
# Non-Null Count  Dtype
# --------------  -----
# 2289 non-null   int64
# dtypes: int64(1)
# memory usage: 18.0 KB

# %%
Y.describe()
# Out:
# count    2289.000000
# mean        1.000000
# std         0.816675
# min         0.000000
# 25%         0.000000
# 50%         1.000000
# 75%         2.000000
# max         2.000000
# Name: -0.05921, dtype: float64

# %% [markdown]
# #Splitting the data

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.2,random_state=42)

# %%
x_train
# Out:
#       -0.05921  0.96082  0.12600  0.31287  -0.57545  -0.58331  -0.91699  \
# 782   -0.05921 -0.28519 -0.31685 -0.58016   0.00332   0.14143  -0.30172
# 1873  -0.61113 -0.57009 -0.31685  2.12700  -0.15487   2.44904   0.94156
# 1689   0.45468  0.96082 -0.31685 -0.46725   0.80523  -0.97631   1.45039
# 237   -1.22751  0.96082 -0.31685  0.52135  -0.15487  -0.71727  -0.60633
# 1684   1.16365 -0.57009 -0.31685  0.13606   0.96248   1.65653   0.43852
# ...        ...      ...      ...      ...       ...       ...       ...
# 1638   1.16365  0.96082 -0.31685 -1.69163   0.47617  -1.42424  -0.30172
# 1095  -0.61113 -0.57009 -0.31685 -0.92104   0.00332   0.72330   0.13136
# 1130  -0.05921 -0.09765 -0.31685 -1.32828   0.16767   1.65653   1.11406
# 1294   0.45468 -0.57009 -0.31685 -2.05048   0.47617   0.58331  -1.34289
# 860   -0.61113  0.24923 -0.31685 -1.86962   1.28610   2.15324   0.76096
#
#       -0.00665  -0.21712  -1.18084  ...  CL0.4  CL0.5  CL0.6  CL0.7  CL0.8  \
# ...

# %% [markdown]
# #Perceptron

# %%
from sklearn.linear_model import Perceptron
pm=Perceptron()
pm.fit(x_train,y_train)
# Out:
# Perceptron()

# %%
yp=pm.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report
print(confusion_matrix(y_test,yp))
# Out:
# [[160   0   0]
#  [ 31  79  40]
#  [  0   0 148]]

# %%
cm = confusion_matrix(y_test, yp)

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %%
print(classification_report(y_test,yp))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      1.00      0.91       160
#            1       1.00      0.53      0.69       150
#            2       0.79      1.00      0.88       148
#
#     accuracy                           0.84       458
#    macro avg       0.87      0.84      0.83       458
# weighted avg       0.87      0.84      0.83       458

# %%
print(accuracy_score(y_test,yp))
# Out:
# 0.8449781659388647

# %% [markdown]
# #LogisticRegression

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
yp = lr.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report
print(confusion_matrix(y_test,yp))
# Out:
# [[160   0   0]
#  [  0 150   0]
#  [  0   0 148]]

# %%
cm = confusion_matrix(y_test, yp)

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %%
print(classification_report(y_test,yp))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       160
#            1       1.00      1.00      1.00       150
#            2       1.00      1.00      1.00       148
#
#     accuracy                           1.00       458
#    macro avg       1.00      1.00      1.00       458
# weighted avg       1.00      1.00      1.00       458

# %%
print(accuracy_score(y_test,yp))
# Out:
# 1.0

# %% [markdown]
# #Support Vector Mechine

# %%
from sklearn.svm import SVC
sv=SVC()
sv.fit(x_train,y_train)
# Out:
# SVC()

# %%
yp=sv.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report
print(confusion_matrix(y_test,yp))
# Out:
# [[156   4   0]
#  [  4 146   0]
#  [  0   3 145]]

# %%
cm = confusion_matrix(y_test, yp)

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %%
print(classification_report(y_test,yp))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97       160
#            1       0.95      0.97      0.96       150
#            2       1.00      0.98      0.99       148
#
#     accuracy                           0.98       458
#    macro avg       0.98      0.98      0.98       458
# weighted avg       0.98      0.98      0.98       458

# %%
print(accuracy_score(y_test,yp))
# Out:
# 0.9759825327510917

# %% [markdown]
# #KNN Model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
model = Sequential()
model.add(Dense(128, activation='relu', input_dim=x_train.shape[1]))
model.add(Dense(64, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model.fit(x_train, y_train, epochs=10, batch_size=32)
# Out:
# Epoch 1/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.3537 - loss: -0.5517
# Epoch 2/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.4144 - loss: -9.6541
# Epoch 3/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.4266 - loss: -50.2601
# Epoch 4/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.4291 - loss: -169.0611
# Epoch 5/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4238 - loss: -374.7859
# Epoch 6/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.4330 - loss: -749.5427
# Epoch 7/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4403 - loss: -1275.8414
# Epoch 8/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4361 - loss: -2257.3884
# Epoch 9/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4411 - loss: -3247.3267
# Epoch 10/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4237 - loss: -5084.8545

# %%
_, accuracy = model.evaluate(x_test, y_test)
print('Accuracy: %.2f' % (accuracy*100))
# Out:
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4456 - loss: -5802.9009
# Accuracy: 44.32

# %%
y_pred = model.predict(x_test)
y_pred = (y_pred > 0.5)
# Out:
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %%
print(confusion_matrix(y_test,y_pred))
# Out:
# [[ 56 104   0]
#  [  3 147   0]
#  [  0 148   0]]

# %%
cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.35      0.51       160
#            1       0.37      0.98      0.54       150
#            2       0.00      0.00      0.00       148
#
#     accuracy                           0.44       458
#    macro avg       0.44      0.44      0.35       458
# weighted avg       0.45      0.44      0.35       458
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %%
print(accuracy_score(y_test,y_pred))
# Out:
# 0.4432314410480349

# %%
value_counts = Y.value_counts()
print(value_counts)
# Out:
# -0.05921
# 2    763
# 1    763
# 0    763
# Name: count, dtype: int64
