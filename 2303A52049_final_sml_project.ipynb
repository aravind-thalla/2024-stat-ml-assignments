# %% [markdown]
# <a href="https://colab.research.google.com/github/aravind-thalla/2024-stat-ml-assignments/blob/main/2303A52049_final_sml_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Reading data

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
data=pd.read_csv('/content/sample_data/drug_consumption.csv')
data.head()
# Out:
#    ID      Age   Gender  Education  Country  Ethnicity   Nscore   Escore  \
# 0   1  0.49788  0.48246   -0.05921  0.96082    0.12600  0.31287 -0.57545
# 1   2 -0.07854 -0.48246    1.98437  0.96082   -0.31685 -0.67825  1.93886
# 2   3  0.49788 -0.48246   -0.05921  0.96082   -0.31685 -0.46725  0.80523
# 3   4 -0.95197  0.48246    1.16365  0.96082   -0.31685 -0.14882 -0.80615
# 4   5  0.49788  0.48246    1.98437  0.96082   -0.31685  0.73545 -1.63340
#
#     Oscore   Ascore  ...  Ecstasy  Heroin  Ketamine Legalh  LSD Meth  \
# 0 -0.58331 -0.91699  ...      CL0     CL0       CL0    CL0  CL0  CL0
# 1  1.43533  0.76096  ...      CL4     CL0       CL2    CL0  CL2  CL3
# 2 -0.84732 -1.62090  ...      CL0     CL0       CL0    CL0  CL0  CL0
# 3 -0.01928  0.59042  ...      CL0     CL0       CL2    CL0  CL0  CL0
# 4 -0.45174 -0.30172  ...      CL1     CL0       CL0    CL1  CL0  CL0
#
#   Mushrooms Nicotine Semer  VSA
# 0       CL0      CL2   CL0  CL0
# 1       CL0      CL4   CL0  CL0
# 2       CL1      CL0   CL0  CL0
# 3       CL0      CL2   CL0  CL0
# 4       CL2      CL2   CL0  CL0
#
# [5 rows x 32 columns]

# %%
target=data['Benzos']
target.head()
# Out:
# 0    CL2
# 1    CL0
# 2    CL0
# 3    CL3
# 4    CL0
# Name: Benzos, dtype: object

# %%
x=data.drop(['Benzos'],axis=1)
x.head()
# Out:
#    ID      Age   Gender  Education  Country  Ethnicity   Nscore   Escore  \
# 0   1  0.49788  0.48246   -0.05921  0.96082    0.12600  0.31287 -0.57545
# 1   2 -0.07854 -0.48246    1.98437  0.96082   -0.31685 -0.67825  1.93886
# 2   3  0.49788 -0.48246   -0.05921  0.96082   -0.31685 -0.46725  0.80523
# 3   4 -0.95197  0.48246    1.16365  0.96082   -0.31685 -0.14882 -0.80615
# 4   5  0.49788  0.48246    1.98437  0.96082   -0.31685  0.73545 -1.63340
#
#     Oscore   Ascore  ...  Ecstasy  Heroin  Ketamine Legalh  LSD Meth  \
# 0 -0.58331 -0.91699  ...      CL0     CL0       CL0    CL0  CL0  CL0
# 1  1.43533  0.76096  ...      CL4     CL0       CL2    CL0  CL2  CL3
# 2 -0.84732 -1.62090  ...      CL0     CL0       CL0    CL0  CL0  CL0
# 3 -0.01928  0.59042  ...      CL0     CL0       CL2    CL0  CL0  CL0
# 4 -0.45174 -0.30172  ...      CL1     CL0       CL0    CL1  CL0  CL0
#
#   Mushrooms Nicotine Semer  VSA
# 0       CL0      CL2   CL0  CL0
# 1       CL0      CL4   CL0  CL0
# 2       CL1      CL0   CL0  CL0
# 3       CL0      CL2   CL0  CL0
# 4       CL2      CL2   CL0  CL0
#
# [5 rows x 31 columns]

# %%
x.isnull().sum()
# Out:
# ID           0
# Age          0
# Gender       0
# Education    0
# Country      0
# Ethnicity    0
# Nscore       0
# Escore       0
# Oscore       0
# Ascore       0
# Cscore       0
# Impulsive    0
# SS           0
# Alcohol      0
# Amphet       0
# Amyl         0
# Caff         0
# Cannabis     0
# Choc         0
# Coke         0
# Crack        0
# Ecstasy      0
# Heroin       0
# Ketamine     0
# Legalh       0
# LSD          0
# Meth         0
# Mushrooms    0
# Nicotine     0
# Semer        0
# VSA          0
# dtype: int64

# %%
x=x.replace({'CL0':'0','CL1':'1','CL2':'2','CL3':'3','CL4':'4','CL5':'5','CL6':'6'})
x
# Out:
#         ID      Age   Gender  Education  Country  Ethnicity   Nscore   Escore  \
# 0        1  0.49788  0.48246   -0.05921  0.96082    0.12600  0.31287 -0.57545
# 1        2 -0.07854 -0.48246    1.98437  0.96082   -0.31685 -0.67825  1.93886
# 2        3  0.49788 -0.48246   -0.05921  0.96082   -0.31685 -0.46725  0.80523
# 3        4 -0.95197  0.48246    1.16365  0.96082   -0.31685 -0.14882 -0.80615
# 4        5  0.49788  0.48246    1.98437  0.96082   -0.31685  0.73545 -1.63340
# ...    ...      ...      ...        ...      ...        ...      ...      ...
# 1880  1884 -0.95197  0.48246   -0.61113 -0.57009   -0.31685 -1.19430  1.74091
# 1881  1885 -0.95197 -0.48246   -0.61113 -0.57009   -0.31685 -0.24649  1.74091
# 1882  1886 -0.07854  0.48246    0.45468 -0.57009   -0.31685  1.13281 -1.37639
# 1883  1887 -0.95197  0.48246   -0.61113 -0.57009   -0.31685  0.91093 -1.92173
# 1884  1888 -0.95197 -0.48246   -0.61113  0.21128   -0.31685 -0.46725  2.12700
#
#        Oscore   Ascore  ...  Ecstasy  Heroin  Ketamine Legalh LSD Meth  \
# 0    -0.58331 -0.91699  ...        0       0         0      0   0    0
# 1     1.43533  0.76096  ...        4       0         2      0   2    3
# 2    -0.84732 -1.62090  ...        0       0         0      0   0    0
# 3    -0.01928  0.59042  ...        0       0         2      0   0    0
# 4    -0.45174 -0.30172  ...        1       0         0      1   0    0
# ...       ...      ...  ...      ...     ...       ...    ...  ..  ...
# 1880  1.88511  0.76096  ...        0       0         0      3   3    0
# 1881  0.58331  0.76096  ...        2       0         0      3   5    4
# 1882 -1.27553 -1.77200  ...        4       0         2      0   2    0
# 1883  0.29338 -1.62090  ...        3       0         0      3   3    0
# 1884  1.65653  1.11406  ...        3       0         0      3   3    0
#
#      Mushrooms Nicotine Semer VSA
# 0            0        2     0   0
# 1            0        4     0   0
# 2            1        0     0   0
# 3            0        2     0   0
# 4            2        2     0   0
# ...        ...      ...   ...  ..
# 1880         0        0     0   5
# 1881         4        5     0   0
# 1882         2        6     0   0
# 1883         3        4     0   0
# 1884         3        6     0   2
#
# [1885 rows x 31 columns]

# %%
x.head()
# Out:
#    ID      Age   Gender  Education  Country  Ethnicity   Nscore   Escore  \
# 0   1  0.49788  0.48246   -0.05921  0.96082    0.12600  0.31287 -0.57545
# 1   2 -0.07854 -0.48246    1.98437  0.96082   -0.31685 -0.67825  1.93886
# 2   3  0.49788 -0.48246   -0.05921  0.96082   -0.31685 -0.46725  0.80523
# 3   4 -0.95197  0.48246    1.16365  0.96082   -0.31685 -0.14882 -0.80615
# 4   5  0.49788  0.48246    1.98437  0.96082   -0.31685  0.73545 -1.63340
#
#     Oscore   Ascore  ...  Ecstasy  Heroin  Ketamine Legalh LSD Meth Mushrooms  \
# 0 -0.58331 -0.91699  ...        0       0         0      0   0    0         0
# 1  1.43533  0.76096  ...        4       0         2      0   2    3         0
# 2 -0.84732 -1.62090  ...        0       0         0      0   0    0         1
# 3 -0.01928  0.59042  ...        0       0         2      0   0    0         0
# 4 -0.45174 -0.30172  ...        1       0         0      1   0    0         2
#
#   Nicotine Semer VSA
# 0        2     0   0
# 1        4     0   0
# 2        0     0   0
# 3        2     0   0
# 4        2     0   0
#
# [5 rows x 31 columns]

# %%
x.shape
# Out:
# (1885, 31)

# %% [markdown]
# #Before resampling data

# %%
x.dtypes
# Out:
# ID             int64
# Age          float64
# Gender       float64
# Education    float64
# Country      float64
# Ethnicity    float64
# Nscore       float64
# Escore       float64
# Oscore       float64
# Ascore       float64
# Cscore       float64
# Impulsive    float64
# SS           float64
# Alcohol       object
# Amphet        object
# Amyl          object
# Caff          object
# Cannabis      object
# Choc          object
# Coke          object
# Crack         object
# Ecstasy       object
# Heroin        object
# Ketamine      object
# Legalh        object
# LSD           object
# Meth          object
# Mushrooms     object
# Nicotine      object
# Semer         object
# VSA           object
# dtype: object

# %%
print(x)
# Out:
#         ID      Age   Gender  Education  Country  Ethnicity   Nscore   Escore  \
# 0        1  0.49788  0.48246   -0.05921  0.96082    0.12600  0.31287 -0.57545
# 1        2 -0.07854 -0.48246    1.98437  0.96082   -0.31685 -0.67825  1.93886
# 2        3  0.49788 -0.48246   -0.05921  0.96082   -0.31685 -0.46725  0.80523
# 3        4 -0.95197  0.48246    1.16365  0.96082   -0.31685 -0.14882 -0.80615
# 4        5  0.49788  0.48246    1.98437  0.96082   -0.31685  0.73545 -1.63340
# ...    ...      ...      ...        ...      ...        ...      ...      ...
# 1880  1884 -0.95197  0.48246   -0.61113 -0.57009   -0.31685 -1.19430  1.74091
# 1881  1885 -0.95197 -0.48246   -0.61113 -0.57009   -0.31685 -0.24649  1.74091
# 1882  1886 -0.07854  0.48246    0.45468 -0.57009   -0.31685  1.13281 -1.37639
# 1883  1887 -0.95197  0.48246   -0.61113 -0.57009   -0.31685  0.91093 -1.92173
# 1884  1888 -0.95197 -0.48246   -0.61113  0.21128   -0.31685 -0.46725  2.12700
#
#        Oscore   Ascore  ...  Ecstasy  Heroin  Ketamine Legalh LSD Meth  \
# 0    -0.58331 -0.91699  ...        0       0         0      0   0    0
# 1     1.43533  0.76096  ...        4       0         2      0   2    3
# 2    -0.84732 -1.62090  ...        0       0         0      0   0    0
# 3    -0.01928  0.59042  ...        0       0         2      0   0    0
# 4    -0.45174 -0.30172  ...        1       0         0      1   0    0
# ...       ...      ...  ...      ...     ...       ...    ...  ..  ...
# 1880  1.88511  0.76096  ...        0       0         0      3   3    0
# 1881  0.58331  0.76096  ...        2       0         0      3   5    4
# 1882 -1.27553 -1.77200  ...        4       0         2      0   2    0
# 1883  0.29338 -1.62090  ...        3       0         0      3   3    0
# 1884  1.65653  1.11406  ...        3       0         0      3   3    0
#
#      Mushrooms Nicotine Semer VSA
# 0            0        2     0   0
# 1            0        4     0   0
# 2            1        0     0   0
# 3            0        2     0   0
# 4            2        2     0   0
# ...        ...      ...   ...  ..
# 1880         0        0     0   5
# 1881         4        5     0   0
# 1882         2        6     0   0
# 1883         3        4     0   0
# 1884         3        6     0   2
#
# [1885 rows x 31 columns]

# %%
for col in x.columns:
  if x[col].dtype == 'object':
    try:
      x[col] = x[col].astype('int64')
    except ValueError:
      x[col] = x[col].astype('float64').astype('int64')

# %%
print(x)
# Out:
#         ID      Age   Gender  Education  Country  Ethnicity   Nscore   Escore  \
# 0        1  0.49788  0.48246   -0.05921  0.96082    0.12600  0.31287 -0.57545
# 1        2 -0.07854 -0.48246    1.98437  0.96082   -0.31685 -0.67825  1.93886
# 2        3  0.49788 -0.48246   -0.05921  0.96082   -0.31685 -0.46725  0.80523
# 3        4 -0.95197  0.48246    1.16365  0.96082   -0.31685 -0.14882 -0.80615
# 4        5  0.49788  0.48246    1.98437  0.96082   -0.31685  0.73545 -1.63340
# ...    ...      ...      ...        ...      ...        ...      ...      ...
# 1880  1884 -0.95197  0.48246   -0.61113 -0.57009   -0.31685 -1.19430  1.74091
# 1881  1885 -0.95197 -0.48246   -0.61113 -0.57009   -0.31685 -0.24649  1.74091
# 1882  1886 -0.07854  0.48246    0.45468 -0.57009   -0.31685  1.13281 -1.37639
# 1883  1887 -0.95197  0.48246   -0.61113 -0.57009   -0.31685  0.91093 -1.92173
# 1884  1888 -0.95197 -0.48246   -0.61113  0.21128   -0.31685 -0.46725  2.12700
#
#        Oscore   Ascore  ...  Ecstasy  Heroin  Ketamine  Legalh  LSD  Meth  \
# 0    -0.58331 -0.91699  ...        0       0         0       0    0     0
# 1     1.43533  0.76096  ...        4       0         2       0    2     3
# 2    -0.84732 -1.62090  ...        0       0         0       0    0     0
# 3    -0.01928  0.59042  ...        0       0         2       0    0     0
# 4    -0.45174 -0.30172  ...        1       0         0       1    0     0
# ...       ...      ...  ...      ...     ...       ...     ...  ...   ...
# 1880  1.88511  0.76096  ...        0       0         0       3    3     0
# 1881  0.58331  0.76096  ...        2       0         0       3    5     4
# 1882 -1.27553 -1.77200  ...        4       0         2       0    2     0
# 1883  0.29338 -1.62090  ...        3       0         0       3    3     0
# 1884  1.65653  1.11406  ...        3       0         0       3    3     0
#
#       Mushrooms  Nicotine  Semer  VSA
# 0             0         2      0    0
# 1             0         4      0    0
# 2             1         0      0    0
# 3             0         2      0    0
# 4             2         2      0    0
# ...         ...       ...    ...  ...
# 1880          0         0      0    5
# 1881          4         5      0    0
# 1882          2         6      0    0
# 1883          3         4      0    0
# 1884          3         6      0    2
#
# [1885 rows x 31 columns]

# %%
x.dtypes
# Out:
# ID             int64
# Age          float64
# Gender       float64
# Education    float64
# Country      float64
# Ethnicity    float64
# Nscore       float64
# Escore       float64
# Oscore       float64
# Ascore       float64
# Cscore       float64
# Impulsive    float64
# SS           float64
# Alcohol        int64
# Amphet         int64
# Amyl           int64
# Caff           int64
# Cannabis       int64
# Choc           int64
# Coke           int64
# Crack          int64
# Ecstasy        int64
# Heroin         int64
# Ketamine       int64
# Legalh         int64
# LSD            int64
# Meth           int64
# Mushrooms      int64
# Nicotine       int64
# Semer          int64
# VSA            int64
# dtype: object

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1885 entries, 0 to 1884
# Data columns (total 31 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ID         1885 non-null   int64
#  1   Age        1885 non-null   float64
#  2   Gender     1885 non-null   float64
#  3   Education  1885 non-null   float64
#  4   Country    1885 non-null   float64
#  5   Ethnicity  1885 non-null   float64
#  6   Nscore     1885 non-null   float64
#  7   Escore     1885 non-null   float64
#  8   Oscore     1885 non-null   float64
#  9   Ascore     1885 non-null   float64
#  10  Cscore     1885 non-null   float64
#  11  Impulsive  1885 non-null   float64
#  12  SS         1885 non-null   float64
#  13  Alcohol    1885 non-null   int64
#  14  Amphet     1885 non-null   int64
#  15  Amyl       1885 non-null   int64
#  16  Caff       1885 non-null   int64
#  17  Cannabis   1885 non-null   int64
#  18  Choc       1885 non-null   int64
#  19  Coke       1885 non-null   int64
#  20  Crack      1885 non-null   int64
#  21  Ecstasy    1885 non-null   int64
#  22  Heroin     1885 non-null   int64
#  23  Ketamine   1885 non-null   int64
#  24  Legalh     1885 non-null   int64
#  25  LSD        1885 non-null   int64
#  26  Meth       1885 non-null   int64
#  27  Mushrooms  1885 non-null   int64
#  28  Nicotine   1885 non-null   int64
#  29  Semer      1885 non-null   int64
#  30  VSA        1885 non-null   int64
# dtypes: float64(12), int64(19)
# memory usage: 456.6 KB

# %%
x.describe()
# Out:
#                 ID         Age       Gender    Education      Country  \
# count  1885.000000  1885.00000  1885.000000  1885.000000  1885.000000
# mean    945.294960     0.03461    -0.000256    -0.003806     0.355542
# std     545.167641     0.87836     0.482588     0.950078     0.700335
# min       1.000000    -0.95197    -0.482460    -2.435910    -0.570090
# 25%     474.000000    -0.95197    -0.482460    -0.611130    -0.570090
# 50%     946.000000    -0.07854    -0.482460    -0.059210     0.960820
# 75%    1417.000000     0.49788     0.482460     0.454680     0.960820
# max    1888.000000     2.59171     0.482460     1.984370     0.960820
#
#          Ethnicity       Nscore       Escore       Oscore       Ascore  ...  \
# count  1885.000000  1885.000000  1885.000000  1885.000000  1885.000000  ...
# mean     -0.309577     0.000047    -0.000163    -0.000534    -0.000245  ...
# std       0.166226     0.998106     0.997448     0.996229     0.997440  ...
# min      -1.107020    -3.464360    -3.273930    -3.273930    -3.464360  ...
# 25%      -0.316850    -0.678250    -0.695090    -0.717270    -0.606330  ...
# 50%      -0.316850     0.042570     0.003320    -0.019280    -0.017290  ...
# 75%      -0.316850     0.629670     0.637790     0.723300     0.760960  ...
# max       1.907250     3.273930     3.273930     2.901610     3.464360  ...
#
#            Ecstasy       Heroin     Ketamine       Legalh          LSD  \
# count  1885.000000  1885.000000  1885.000000  1885.000000  1885.000000
# mean      1.314058     0.374005     0.569231     1.355968     1.061538
# std       1.647567     1.034779     1.220015     1.789647     1.491103
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.000000     0.000000     0.000000     0.000000
# 50%       0.000000     0.000000     0.000000     0.000000     0.000000
# 75%       3.000000     0.000000     0.000000     3.000000     2.000000
# max       6.000000     6.000000     6.000000     6.000000     6.000000
#
#               Meth    Mushrooms     Nicotine        Semer          VSA
# count  1885.000000  1885.000000  1885.000000  1885.000000  1885.000000
# mean      0.826525     1.187268     3.200531     0.009549     0.433422
# std       1.646632     1.466341     2.413932     0.159331     0.962375
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.000000     1.000000     0.000000     0.000000
# 50%       0.000000     0.000000     3.000000     0.000000     0.000000
# 75%       0.000000     2.000000     6.000000     0.000000     0.000000
# max       6.000000     6.000000     6.000000     4.000000     6.000000
#
# [8 rows x 31 columns]

# %%
x.corr()
# Out:
#                  ID       Age    Gender  Education   Country  Ethnicity  \
# ID         1.000000 -0.271395 -0.025467  -0.025253 -0.340751   0.059309
# Age       -0.271395  1.000000  0.110286   0.158811  0.354241  -0.069753
# Gender    -0.025467  0.110286  1.000000   0.196774  0.216271  -0.001213
# Education -0.025253  0.158811  0.196774   1.000000  0.225311  -0.036099
# Country   -0.340751  0.354241  0.216271   0.225311  1.000000  -0.127946
# Ethnicity  0.059309 -0.069753 -0.001213  -0.036099 -0.127946   1.000000
# Nscore     0.018639 -0.136654  0.074646  -0.100993 -0.136191   0.047642
# Escore    -0.046960 -0.033849  0.057864   0.115645  0.109524   0.018402
# Oscore     0.173565 -0.226778 -0.131021   0.057994 -0.341969   0.084816
# Ascore    -0.028782  0.063504  0.219743   0.091088  0.150921  -0.038726
# Cscore    -0.072094  0.183564  0.183831   0.240417  0.214000  -0.029923
# Impulsive  0.119663 -0.190939 -0.167492  -0.132482 -0.231572   0.082411
# SS         0.165882 -0.332188 -0.244277  -0.131146 -0.345415   0.100304
# Alcohol   -0.020281 -0.028773 -0.002537   0.130657  0.076361   0.053825
# Amphet     0.168624 -0.246748 -0.222440  -0.153895 -0.395836   0.084407
# Amyl      -0.029705 -0.098108 -0.162250  -0.002560  0.080596   0.038790
# Caff      -0.006448  0.037413 -0.011195   0.036019  0.004974   0.084292
# Cannabis   0.209274 -0.446846 -0.301579  -0.265405 -0.551938   0.136049
# Choc      -0.060475  0.047522  0.074584   0.027837  0.124505   0.024475
# Coke       0.091650 -0.220664 -0.176704  -0.108433 -0.277531   0.086853
# Crack      0.082169 -0.051355 -0.151324  -0.147743 -0.229899   0.035478
# Ecstasy    0.167231 -0.384784 -0.228574  -0.159819 -0.336328   0.071826
# Heroin     0.091180 -0.121675 -0.136728  -0.131051 -0.300210   0.042881
# Ketamine   0.074800 -0.220689 -0.189825  -0.076479 -0.112577   0.031961
# Legalh     0.220806 -0.419839 -0.315676  -0.208656 -0.426030   0.077511
# LSD        0.215234 -0.323207 -0.278983  -0.177817 -0.498263   0.129031
# Meth       0.175429 -0.191503 -0.181489  -0.170103 -0.413946   0.063805
# Mushrooms  0.202910 -0.331456 -0.272431  -0.169762 -0.490052   0.115962
# Nicotine   0.063197 -0.248883 -0.192084  -0.240547 -0.277913   0.077724
# Semer      0.050454 -0.049729  0.013354  -0.036342 -0.068018   0.022716
# VSA        0.101165 -0.229657 -0.134852  -0.120540 -0.267033   0.087011
#
#              Nscore    Escore    Oscore    Ascore  ...   Ecstasy    Heroin  \
# ID         0.018639 -0.046960  0.173565 -0.028782  ...  0.167231  0.091180
# Age       -0.136654 -0.033849 -0.226778  0.063504  ... -0.384784 -0.121675
# Gender     0.074646  0.057864 -0.131021  0.219743  ... -0.228574 -0.136728
# Education -0.100993  0.115645  0.057994  0.091088  ... -0.159819 -0.131051
# Country   -0.136191  0.109524 -0.341969  0.150921  ... -0.336328 -0.300210
# Ethnicity  0.047642  0.018402  0.084816 -0.038726  ...  0.071826  0.042881
# Nscore     1.000000 -0.431051  0.010177 -0.216964  ...  0.069948  0.172685
# Escore    -0.431051  1.000000  0.245277  0.157336  ...  0.078822 -0.079998
# Oscore     0.010177  0.245277  1.000000  0.038516  ...  0.296306  0.134194
# Ascore    -0.216964  0.157336  0.038516  1.000000  ... -0.114550 -0.169886
# Cscore    -0.391088  0.308024 -0.056811  0.247482  ... -0.217335 -0.158398
# Impulsive  0.174399  0.114151  0.277512 -0.229690  ...  0.260864  0.197701
# SS         0.079988  0.210130  0.421709 -0.208061  ...  0.388186  0.213684
# Alcohol   -0.001882  0.092303  0.032711 -0.021806  ...  0.073585 -0.033786
# Amphet     0.131120 -0.041095  0.221116 -0.148868  ...  0.521537  0.360896
# Amyl       0.033317  0.030199  0.060511 -0.096057  ...  0.358947  0.129242
# Caff       0.013032  0.054343  0.027304 -0.016190  ...  0.033983  0.014683
# Cannabis   0.095535 -0.014369  0.414163 -0.148481  ...  0.552978  0.233546
# Choc       0.012583  0.020305  0.001239  0.036266  ... -0.049131 -0.078250
# Coke       0.139915  0.030942  0.188276 -0.198147  ...  0.610783  0.424215
# Crack      0.111435 -0.050969  0.097002 -0.103945  ...  0.232394  0.527120
# Ecstasy    0.069948  0.078822  0.296306 -0.114550  ...  1.000000  0.265752
# Heroin     0.172685 -0.079998  0.134194 -0.169886  ...  0.265752  1.000000
# Ketamine   0.062750  0.018727  0.185061 -0.110763  ...  0.508329  0.249613
# Legalh     0.113342 -0.037383  0.317322 -0.139983  ...  0.554134  0.242205
# LSD        0.037095  0.018166  0.369759 -0.093888  ...  0.570946  0.279543
# Meth       0.184672 -0.121708  0.171984 -0.156847  ...  0.259177  0.478264
# Mushrooms  0.042386  0.021105  0.369139 -0.111424  ...  0.547536  0.268299
# Nicotine   0.128430 -0.019196  0.195460 -0.111075  ...  0.380399  0.224314
# Semer     -0.001673  0.022909  0.026774  0.019750  ...  0.039119  0.016959
# VSA        0.115086 -0.032910  0.150502 -0.114083  ...  0.251542  0.256073
#
#            Ketamine    Legalh       LSD      Meth  Mushrooms  Nicotine  \
# ID         0.074800  0.220806  0.215234  0.175429   0.202910  0.063197
# Age       -0.220689 -0.419839 -0.323207 -0.191503  -0.331456 -0.248883
# Gender    -0.189825 -0.315676 -0.278983 -0.181489  -0.272431 -0.192084
# Education -0.076479 -0.208656 -0.177817 -0.170103  -0.169762 -0.240547
# Country   -0.112577 -0.426030 -0.498263 -0.413946  -0.490052 -0.277913
# Ethnicity  0.031961  0.077511  0.129031  0.063805   0.115962  0.077724
# Nscore     0.062750  0.113342  0.037095  0.184672   0.042386  0.128430
# Escore     0.018727 -0.037383  0.018166 -0.121708   0.021105 -0.019196
# Oscore     0.185061  0.317322  0.369759  0.171984   0.369139  0.195460
# Ascore    -0.110763 -0.139983 -0.093888 -0.156847  -0.111424 -0.111075
# Cscore    -0.153482 -0.254417 -0.160699 -0.191380  -0.191237 -0.230862
# Impulsive  0.177665  0.267579  0.229205  0.181524   0.263684  0.246299
# SS         0.243609  0.405578  0.365536  0.218884   0.378285  0.305635
# Alcohol    0.065895  0.027828  0.012123 -0.079022   0.027419  0.062264
# Amphet     0.373587  0.474993  0.419616  0.397671   0.427977  0.352249
# Amyl       0.343731  0.260235  0.161425  0.057083   0.212167  0.223269
# Caff       0.013997  0.006747 -0.004510  0.023196   0.040013  0.126669
# Cannabis   0.309144  0.554048  0.521048  0.295021   0.579934  0.515145
# Choc      -0.026126 -0.055693 -0.078222 -0.044426  -0.073984 -0.040433
# Coke       0.441656  0.412975  0.384027  0.343801   0.426584  0.401253
# Crack      0.229557  0.194630  0.230271  0.355952   0.261605  0.241017
# Ecstasy    0.508329  0.554134  0.570946  0.259177   0.547536  0.380399
# Heroin     0.249613  0.242205  0.279543  0.478264   0.268299  0.224314
# Ketamine   1.000000  0.410852  0.409933  0.186836   0.410059  0.255897
# Legalh     0.410852  1.000000  0.471942  0.324824   0.531819  0.341127
# LSD        0.409933  0.471942  1.000000  0.266792   0.668627  0.292235
# Meth       0.186836  0.324824  0.266792  1.000000   0.277258  0.220544
# Mushrooms  0.410059  0.531819  0.668627  0.277258   1.000000  0.323034
# Nicotine   0.255897  0.341127  0.292235  0.220544   0.323034  1.000000
# Semer      0.059400  0.015995  0.071252 -0.003798   0.099120  0.026760
# VSA        0.196172  0.319639  0.286189  0.258825   0.245239  0.255023
#
#               Semer       VSA
# ID         0.050454  0.101165
# Age       -0.049729 -0.229657
# Gender     0.013354 -0.134852
# Education -0.036342 -0.120540
# Country   -0.068018 -0.267033
# Ethnicity  0.022716  0.087011
# Nscore    -0.001673  0.115086
# Escore     0.022909 -0.032910
# Oscore     0.026774  0.150502
# Ascore     0.019750 -0.114083
# Cscore     0.008524 -0.159442
# Impulsive  0.011178  0.181019
# SS         0.047986  0.250599
# Alcohol   -0.036110  0.025353
# Amphet     0.029641  0.269259
# Amyl       0.006498  0.151936
# Caff      -0.011084  0.057259
# Cannabis   0.043969  0.271175
# Choc      -0.039510 -0.073982
# Coke       0.046451  0.281865
# Crack      0.026438  0.250285
# Ecstasy    0.039119  0.251542
# Heroin     0.016959  0.256073
# Ketamine   0.059400  0.196172
# Legalh     0.015995  0.319639
# LSD        0.071252  0.286189
# Meth      -0.003798  0.258825
# Mushrooms  0.099120  0.245239
# Nicotine   0.026760  0.255023
# Semer      1.000000  0.056072
# VSA        0.056072  1.000000
#
# [31 rows x 31 columns]

# %%
plt.figure(figsize=(12, 10))
sns.heatmap(x.corr(), annot=True, cmap='coolwarm')
plt.show()

# %%
target.value_counts()
# Out:
# Benzos
# CL0    1000
# CL3     236
# CL2     234
# CL4     120
# CL1     116
# CL6      95
# CL5      84
# Name: count, dtype: int64

# %%
target.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 1885 entries, 0 to 1884
# Series name: Benzos
# Non-Null Count  Dtype
# --------------  -----
# 1885 non-null   object
# dtypes: object(1)
# memory usage: 14.9+ KB

# %%
target.describe()
# Out:
# count     1885
# unique       7
# top        CL0
# freq      1000
# Name: Benzos, dtype: object

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,target,test_size=0.2,random_state=42)

# %%
x_train
# Out:
#         ID      Age   Gender  Education  Country  Ethnicity   Nscore   Escore  \
# 1814  1818 -0.95197  0.48246   -0.61113 -0.57009    0.11440 -0.05188 -1.23177
# 710    713 -0.07854  0.48246    1.16365  0.96082   -0.31685  0.52135  0.32197
# 931    935 -0.95197  0.48246    0.45468  0.96082   -0.31685 -0.24649  0.00332
# 617    620 -0.07854  0.48246    0.45468  0.96082   -0.31685 -0.05188  1.11406
# 1797  1801  1.09449 -0.48246   -0.61113 -0.57009   -0.31685  2.28554 -1.23177
# ...    ...      ...      ...        ...      ...        ...      ...      ...
# 1130  1134 -0.07854 -0.48246    1.16365 -0.46841   -0.31685  0.62967 -0.69509
# 1294  1298 -0.95197 -0.48246   -0.61113 -0.57009    0.11440 -0.34799  0.00332
# 860    864 -0.95197 -0.48246    0.45468  0.96082   -0.31685  0.04257 -0.15487
# 1459  1463 -0.07854 -0.48246    1.16365  0.96082   -0.31685  0.13606  0.16767
# 1126  1130 -0.95197 -0.48246   -0.61113 -0.57009   -0.31685  1.02119 -2.03972
#
#        Oscore   Ascore  ...  Ecstasy  Heroin  Ketamine  Legalh  LSD  Meth  \
# 1814  0.29338  1.11406  ...        2       0         0       3    0     2
# 710   0.72330  0.13136  ...        3       0         0       3    3     0
# 931   1.06238  0.59042  ...        0       0         0       0    0     0
# 617   0.88309  0.13136  ...        0       0         0       0    0     0
# 1797 -0.01928 -2.53830  ...        0       0         0       0    1     6
# ...       ...      ...  ...      ...     ...       ...     ...  ...   ...
# 1130  0.14143 -1.21213  ...        2       2         2       6    2     3
# 1294  0.58331 -0.15487  ...        3       3         2       3    3     3
# 860  -0.17779 -0.60633  ...        2       0         2       2    4     2
# 1459 -0.45174  0.43852  ...        2       0         0       2    0     5
# 1126 -0.71727  1.11406  ...        3       0         0       2    3     6
#
#       Mushrooms  Nicotine  Semer  VSA
# 1814          0         4      0    2
# 710           0         0      0    0
# 931           0         0      0    0
# 617           0         2      0    0
# 1797          1         0      0    1
# ...         ...       ...    ...  ...
# 1130          3         3      0    6
# 1294          3         5      0    0
# 860           2         4      0    0
# 1459          0         6      0    0
# 1126          2         6      0    2
#
# [1508 rows x 31 columns]

# %%
x_train.hist(bins=20, figsize=(10,10))
plt.show()

# %%
sns.heatmap(x_train.corr(), annot=True, cmap='coolwarm')
plt.show()

# %% [markdown]
# ##Perceptron

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report,ConfusionMatrixDisplay,roc_curve,auc,precision_recall_curve

# %%
from sklearn.linear_model import Perceptron
pm=Perceptron()
pm.fit(x_train,y_train)
# Out:
# Perceptron()

# %%
yp=pm.predict(x_test)

# %%
cm = confusion_matrix(y_test,yp)
print(cm)
# Out:
# [[  9   1   0   0 193   0   0]
#  [  0   1   0   0  20   0   0]
#  [  0   0   0   0  38   0   0]
#  [  1   0   0   0  50   0   0]
#  [  0   0   0   0  27   0   0]
#  [  0   1   0   0  14   0   0]
#  [  1   0   0   0  21   0   0]]

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %%
from sklearn.linear_model import Perceptron
from sklearn.preprocessing import label_binarize
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt
import numpy as np
y_scores = pm.decision_function(x_test)

# Binarize the output for multiclass
y_test_binarized = label_binarize(y_test, classes=np.unique(y_test))

# Compute ROC curve and AUC for each class
plt.figure(figsize=(8, 6))
for i in range(y_test_binarized.shape[1]):
    fpr, tpr, _ = roc_curve(y_test_binarized[:, i], y_scores[:, i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, label=f'Class {i} (AUC = {roc_auc:.2f})')

plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend()
plt.show()

# %%
from sklearn.metrics import precision_recall_curve
from sklearn.preprocessing import label_binarize
import matplotlib.pyplot as plt
import numpy as np
y_scores = pm.decision_function(x_test)

# Binarize the test labels
classes = np.unique(y_test)
y_test_binarized = label_binarize(y_test, classes=classes)

# Plot Precision-Recall Curve for each class
plt.figure(figsize=(8, 6))
for i, class_label in enumerate(classes):
    precision, recall, _ = precision_recall_curve(y_test_binarized[:, i], y_scores[:, i])  # Use y_scores
    plt.plot(recall, precision, marker='.', label=f'Class {class_label}')

plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.legend()
plt.show()

# %%
print(classification_report(y_test,yp))
# Out:
#               precision    recall  f1-score   support
#
#          CL0       0.82      0.04      0.08       203
#          CL1       0.33      0.05      0.08        21
#          CL2       0.00      0.00      0.00        38
#          CL3       0.00      0.00      0.00        51
#          CL4       0.07      1.00      0.14        27
#          CL5       0.00      0.00      0.00        15
#          CL6       0.00      0.00      0.00        22
#
#     accuracy                           0.10       377
#    macro avg       0.18      0.16      0.04       377
# weighted avg       0.46      0.10      0.06       377
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
accuracy_perceptron = accuracy_score(y_test,yp)
print(accuracy_perceptron)
# Out:
# 0.09814323607427056

# %%
importance = pm.coef_[0]
plt.bar([x for x in range(len(importance))], importance)
plt.title("Feature Importance")
plt.show()

# %% [markdown]
# ##LogisticRegression

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
yp = lr.predict(x_test)

# %%
cm = confusion_matrix(y_test, yp)
print(cm)
# Out:
# [[195   0   0   8   0   0   0]
#  [ 18   0   3   0   0   0   0]
#  [ 25   0   6   6   0   0   1]
#  [ 26   0   4  15   4   0   2]
#  [ 12   0   2   5   3   0   5]
#  [  8   0   0   4   3   0   0]
#  [  4   0   3  11   2   0   2]]

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %%
from sklearn.linear_model import Perceptron
from sklearn.preprocessing import label_binarize
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt
import numpy as np

y_scores = pm.decision_function(x_test)

# Binarize the output for multiclass
y_test_binarized = label_binarize(y_test, classes=np.unique(y_test))

# Compute ROC curve and AUC for each class
plt.figure(figsize=(8, 6))
for i in range(y_test_binarized.shape[1]):
    fpr, tpr, _ = roc_curve(y_test_binarized[:, i], y_scores[:, i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, label=f'Class {i} (AUC = {roc_auc:.2f})')

plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend()
plt.show()

# %%
from sklearn.metrics import precision_recall_curve
from sklearn.preprocessing import label_binarize
import matplotlib.pyplot as plt
import numpy as np
y_scores = pm.decision_function(x_test)

# Binarize the test labels
classes = np.unique(y_test)
y_test_binarized = label_binarize(y_test, classes=classes)

# Plot Precision-Recall Curve for each class
plt.figure(figsize=(8, 6))
for i, class_label in enumerate(classes):
    precision, recall, _ = precision_recall_curve(y_test_binarized[:, i], y_scores[:, i])  # Use y_scores
    plt.plot(recall, precision, marker='.', label=f'Class {class_label}')

plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.legend()
plt.show()

# %%
importance = lr.coef_[0]
plt.bar([x for x in range(len(importance))], importance)
plt.title("Feature Importance")
plt.show()

# %%
print(classification_report(y_test,yp))
# Out:
#               precision    recall  f1-score   support
#
#          CL0       0.68      0.96      0.79       203
#          CL1       0.00      0.00      0.00        21
#          CL2       0.33      0.16      0.21        38
#          CL3       0.31      0.29      0.30        51
#          CL4       0.25      0.11      0.15        27
#          CL5       0.00      0.00      0.00        15
#          CL6       0.20      0.09      0.12        22
#
#     accuracy                           0.59       377
#    macro avg       0.25      0.23      0.23       377
# weighted avg       0.47      0.59      0.51       377
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
accuracy_logistic=accuracy_score(y_test,yp)
print(accuracy_logistic)
# Out:
# 0.5862068965517241

# %%
from sklearn.svm import SVC
sv=SVC()
sv.fit(x_train,y_train)
# Out:
# SVC()

# %%
yp=sv.predict(x_test)

# %%
cm = confusion_matrix(y_test, yp)
print(cm)
# Out:
# [[203   0   0   0   0   0   0]
#  [ 21   0   0   0   0   0   0]
#  [ 38   0   0   0   0   0   0]
#  [ 51   0   0   0   0   0   0]
#  [ 27   0   0   0   0   0   0]
#  [ 15   0   0   0   0   0   0]
#  [ 22   0   0   0   0   0   0]]

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %%
from sklearn.linear_model import Perceptron
from sklearn.preprocessing import label_binarize
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt
import numpy as np

y_scores = pm.decision_function(x_test)

# Binarize the output for multiclass
y_test_binarized = label_binarize(y_test, classes=np.unique(y_test))

# Compute ROC curve and AUC for each class
plt.figure(figsize=(8, 6))
for i in range(y_test_binarized.shape[1]):
    fpr, tpr, _ = roc_curve(y_test_binarized[:, i], y_scores[:, i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, label=f'Class {i} (AUC = {roc_auc:.2f})')

plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend()
plt.show()

# %%
from sklearn.metrics import precision_recall_curve
from sklearn.preprocessing import label_binarize
import matplotlib.pyplot as plt
import numpy as np
y_scores = pm.decision_function(x_test)

# Binarize the test labels
classes = np.unique(y_test)
y_test_binarized = label_binarize(y_test, classes=classes)

# Plot Precision-Recall Curve for each class
plt.figure(figsize=(8, 6))
for i, class_label in enumerate(classes):
    precision, recall, _ = precision_recall_curve(y_test_binarized[:, i], y_scores[:, i])  # Use y_scores
    plt.plot(recall, precision, marker='.', label=f'Class {class_label}')

plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.legend()
plt.show()

# %%
print(classification_report(y_test,yp))
# Out:
#               precision    recall  f1-score   support
#
#          CL0       0.54      1.00      0.70       203
#          CL1       0.00      0.00      0.00        21
#          CL2       0.00      0.00      0.00        38
#          CL3       0.00      0.00      0.00        51
#          CL4       0.00      0.00      0.00        27
#          CL5       0.00      0.00      0.00        15
#          CL6       0.00      0.00      0.00        22
#
#     accuracy                           0.54       377
#    macro avg       0.08      0.14      0.10       377
# weighted avg       0.29      0.54      0.38       377
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
accuracy_svc = accuracy_score(y_test,yp)
print(accuracy_svc)
# Out:
# 0.5384615384615384

# %% [markdown]
# #After resampling the data

# %%
from imblearn.over_sampling import SMOTE

smote = SMOTE()
X,Y= smote.fit_resample(x,target)

# %%
Y.value_counts()
# Out:
# Benzos
# CL2    1000
# CL0    1000
# CL3    1000
# CL1    1000
# CL4    1000
# CL5    1000
# CL6    1000
# Name: count, dtype: int64

# %%
Y.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 7000 entries, 0 to 6999
# Series name: Benzos
# Non-Null Count  Dtype
# --------------  -----
# 7000 non-null   object
# dtypes: object(1)
# memory usage: 54.8+ KB

# %%
Y.describe()
# Out:
# count     7000
# unique       7
# top        CL2
# freq      1000
# Name: Benzos, dtype: object

# %% [markdown]
# #Splitting the data

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.2,random_state=42)

# %%
x_train
# Out:
#         ID       Age    Gender  Education   Country  Ethnicity    Nscore  \
# 1032  1036 -0.951970 -0.482460  -0.059210  0.960820  -0.316850  0.521350
# 6339  1826 -0.078540  0.482460   0.123415 -0.513986   0.029476  0.933407
# 3886  1582  0.309511  0.482460   0.284680  0.960820  -0.316850  0.428871
# 2653   691  1.694911  0.389762   0.993150  0.813748  -0.316850  0.670265
# 6914   447  0.048607  0.482460   0.341326 -0.232402  -0.316850  2.528505
# ...    ...       ...       ...        ...       ...        ...       ...
# 3772  1658 -0.149097 -0.482460  -0.611130  0.306713  -0.316850 -1.551540
# 5191   271  0.908981 -0.482460   1.324790  0.960820  -0.316850  0.282325
# 5226  1856 -0.752850  0.482460   0.454680 -0.570090  -0.316850  1.496449
# 5390   356  1.266370  0.371688   0.630288  0.960820  -0.316850 -0.997344
# 860    864 -0.951970 -0.482460   0.454680  0.960820  -0.316850  0.042570
#
#         Escore    Oscore    Ascore  ...  Ecstasy  Heroin  Ketamine  Legalh  \
# 1032  0.476170  1.885110 -0.017290  ...        4       0         4       3
# 6339 -1.342241 -0.167386 -1.452638  ...        0       1         0       0
# 3886  0.852028  0.333919  0.429325  ...        2       0         0       2
# 2653 -0.657166 -0.464380 -0.073878  ...        0       0         0       0
# 6914 -0.496260 -0.818634 -1.648504  ...        0       1         0       1
# ...        ...       ...       ...  ...      ...     ...       ...     ...
# 3772  0.231876 -0.158275 -0.465579  ...        0       2         0       0
# 5191  0.743100  0.024967 -1.027443  ...        0       0         0       0
# 5226 -1.045500  0.666778 -1.111910  ...        3       0         2       4
# 5390  0.403727  0.207841  0.218326  ...        0       0         0       0
# 860  -0.154870 -0.177790 -0.606330  ...        2       0         2       2
#
#       LSD  Meth  Mushrooms  Nicotine  Semer  VSA
# 1032    0     0          0         6      0    0
# 6339    1     2          0         1      0    0
# 3886    0     0          1         2      0    0
# 2653    1     0          1         1      0    0
# 6914    0     1          1         6      0    0
# ...   ...   ...        ...       ...    ...  ...
# 3772    0     3          0         4      0    0
# 5191    0     0          0         4      0    0
# 5226    2     3          2         6      0    0
# 5390    0     1          0         1      0    0
# 860     4     2          2         4      0    0
#
# [5600 rows x 31 columns]

# %%
x_train.hist(bins=20, figsize=(10,10))
plt.show()

# %%
sns.heatmap(x_train.corr(), annot=True, cmap='coolwarm')
plt.show()

# %% [markdown]
# ##Perceptron

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report,ConfusionMatrixDisplay,roc_curve,auc,precision_recall_curve

# %%
from sklearn.linear_model import Perceptron
pm=Perceptron()
pm.fit(x_train,y_train)
# Out:
# Perceptron()

# %%
yp=pm.predict(x_test)

# %%
cm = confusion_matrix(y_test,yp)
print(cm)
# Out:
# [[  0  27   0   0   0 194   1]
#  [  0  38   0   0   0 151   0]
#  [  0  10   0   0   0 190   0]
#  [  0  11   0   0   0 190   0]
#  [  0   1   0   0   0 192   0]
#  [  0   3   0   0   0 203   0]
#  [  0   0   0   0   0 189   0]]

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %%
print(classification_report(y_test,yp))
# Out:
#               precision    recall  f1-score   support
#
#          CL0       0.00      0.00      0.00       222
#          CL1       0.42      0.20      0.27       189
#          CL2       0.00      0.00      0.00       200
#          CL3       0.00      0.00      0.00       201
#          CL4       0.00      0.00      0.00       193
#          CL5       0.16      0.99      0.27       206
#          CL6       0.00      0.00      0.00       189
#
#     accuracy                           0.17      1400
#    macro avg       0.08      0.17      0.08      1400
# weighted avg       0.08      0.17      0.08      1400
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
accuracy_perceptron = accuracy_score(y_test,yp)
print(accuracy_perceptron)
# Out:
# 0.17214285714285715

# %% [markdown]
# ##LogisticRegression

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
yp = lr.predict(x_test)

# %%
cm = confusion_matrix(y_test, yp)
print(cm)
# Out:
# [[103  44  31  19  10  12   3]
#  [ 25  95  49   4   2   8   6]
#  [ 45  35  52  34  12  10  12]
#  [ 20  22  28  35  45  23  28]
#  [ 21   7  22  27  63  27  26]
#  [  2  19  26  17  34  62  46]
#  [ 11   8  15  11  23  29  92]]

# %%
print(classification_report(y_test,yp))
# Out:
#               precision    recall  f1-score   support
#
#          CL0       0.45      0.46      0.46       222
#          CL1       0.41      0.50      0.45       189
#          CL2       0.23      0.26      0.25       200
#          CL3       0.24      0.17      0.20       201
#          CL4       0.33      0.33      0.33       193
#          CL5       0.36      0.30      0.33       206
#          CL6       0.43      0.49      0.46       189
#
#     accuracy                           0.36      1400
#    macro avg       0.35      0.36      0.35      1400
# weighted avg       0.35      0.36      0.35      1400

# %%
accuracy_logistic=accuracy_score(y_test,yp)
print(accuracy_logistic)
# Out:
# 0.3585714285714286

# %% [markdown]
# ##Support Vector Mechine

# %%
from sklearn.svm import SVC
sv=SVC()
sv.fit(x_train,y_train)
# Out:
# SVC()

# %%
yp=sv.predict(x_test)

# %%
cm = confusion_matrix(y_test, yp)
print(cm)
# Out:
# [[  0  91  28  10  64   0  29]
#  [  0 100  23   4  29   0  33]
#  [  0  57  30   6  45   0  62]
#  [  0  33  27   5  92   0  44]
#  [  0  23  23   2  88   0  57]
#  [  0  28  24   3  72   0  79]
#  [  0  28  43   0  53   0  65]]

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %%
print(classification_report(y_test,yp))
# Out:
#               precision    recall  f1-score   support
#
#          CL0       0.00      0.00      0.00       222
#          CL1       0.28      0.53      0.36       189
#          CL2       0.15      0.15      0.15       200
#          CL3       0.17      0.02      0.04       201
#          CL4       0.20      0.46      0.28       193
#          CL5       0.00      0.00      0.00       206
#          CL6       0.18      0.34      0.23       189
#
#     accuracy                           0.21      1400
#    macro avg       0.14      0.21      0.15      1400
# weighted avg       0.13      0.21      0.15      1400
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
accuracy_svc = accuracy_score(y_test,yp)
print(accuracy_svc)
# Out:
# 0.2057142857142857

# %% [markdown]
# #BootStraping

# %%
from sklearn.utils import resample
def bootstrapping(x_train,y_train):
    x_train_boot, y_train_boot = resample(x_train, y_train, replace=True, n_samples=len(x_train), random_state=42)
    return x_train_boot,y_train_boot

# %%
x_train_boot,y_train_boot= bootstrapping(x_train,y_train)

# %% [markdown]
# #Perceptron

# %%
from sklearn.linear_model import Perceptron
pm=Perceptron()
pm.fit(x_train,y_train)
# Out:
# Perceptron()

# %%
yp=pm.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report
print(confusion_matrix(y_test,yp))
# Out:
# [[  0  27   0   0   0 194   1]
#  [  0  38   0   0   0 151   0]
#  [  0  10   0   0   0 190   0]
#  [  0  11   0   0   0 190   0]
#  [  0   1   0   0   0 192   0]
#  [  0   3   0   0   0 203   0]
#  [  0   0   0   0   0 189   0]]

# %%
cm = confusion_matrix(y_test, yp)

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %%
print(classification_report(y_test,yp))
# Out:
#               precision    recall  f1-score   support
#
#          CL0       0.00      0.00      0.00       222
#          CL1       0.42      0.20      0.27       189
#          CL2       0.00      0.00      0.00       200
#          CL3       0.00      0.00      0.00       201
#          CL4       0.00      0.00      0.00       193
#          CL5       0.16      0.99      0.27       206
#          CL6       0.00      0.00      0.00       189
#
#     accuracy                           0.17      1400
#    macro avg       0.08      0.17      0.08      1400
# weighted avg       0.08      0.17      0.08      1400
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
print(accuracy_score(y_test,yp))
# Out:
# 0.17214285714285715

# %% [markdown]
# #LogisticRegression

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
yp = lr.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report
print(confusion_matrix(y_test,yp))
# Out:
# [[103  44  31  19  10  12   3]
#  [ 25  95  49   4   2   8   6]
#  [ 45  35  52  34  12  10  12]
#  [ 20  22  28  35  45  23  28]
#  [ 21   7  22  27  63  27  26]
#  [  2  19  26  17  34  62  46]
#  [ 11   8  15  11  23  29  92]]

# %%
cm = confusion_matrix(y_test, yp)

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %%
print(classification_report(y_test,yp))
# Out:
#               precision    recall  f1-score   support
#
#          CL0       0.45      0.46      0.46       222
#          CL1       0.41      0.50      0.45       189
#          CL2       0.23      0.26      0.25       200
#          CL3       0.24      0.17      0.20       201
#          CL4       0.33      0.33      0.33       193
#          CL5       0.36      0.30      0.33       206
#          CL6       0.43      0.49      0.46       189
#
#     accuracy                           0.36      1400
#    macro avg       0.35      0.36      0.35      1400
# weighted avg       0.35      0.36      0.35      1400

# %%
print(accuracy_score(y_test,yp))
# Out:
# 0.3585714285714286

# %% [markdown]
# #Support Vector Mechine

# %%
from sklearn.svm import SVC
sv=SVC()
sv.fit(x_train,y_train)
# Out:
# SVC()

# %%
yp=sv.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report
print(confusion_matrix(y_test,yp))
# Out:
# [[  0  91  28  10  64   0  29]
#  [  0 100  23   4  29   0  33]
#  [  0  57  30   6  45   0  62]
#  [  0  33  27   5  92   0  44]
#  [  0  23  23   2  88   0  57]
#  [  0  28  24   3  72   0  79]
#  [  0  28  43   0  53   0  65]]

# %%
cm = confusion_matrix(y_test, yp)

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %%
print(classification_report(y_test,yp))
# Out:
#               precision    recall  f1-score   support
#
#          CL0       0.00      0.00      0.00       222
#          CL1       0.28      0.53      0.36       189
#          CL2       0.15      0.15      0.15       200
#          CL3       0.17      0.02      0.04       201
#          CL4       0.20      0.46      0.28       193
#          CL5       0.00      0.00      0.00       206
#          CL6       0.18      0.34      0.23       189
#
#     accuracy                           0.21      1400
#    macro avg       0.14      0.21      0.15      1400
# weighted avg       0.13      0.21      0.15      1400
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
print(accuracy_score(y_test,yp))
# Out:
# 0.2057142857142857

# %% [markdown]
# ---
#
# #Comparision

# %%
model_names = ['Perceptron', 'Logistic Regression', 'SVC',]
accuracies = [accuracy_perceptron, accuracy_logistic, accuracy_svc]

plt.bar(model_names, accuracies)
plt.xlabel('Models')
plt.ylabel('Accuracy')
plt.title('Comparison of Model Accuracies')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Example Data
scenarios = ['Before SMOT', 'After SMOT', 'Bootstrapping']
models = ['Perceptron', 'Logistic', 'SVC']
accuracies = {
    'Perceptron': [0.09814323607427056 , 0.16857142857142857, 0.16857142857142857 ],
    'Logistic': [0.5862068965517241, 0.3535714285714286 , 0.3535714285714286],
    'SVC': [0.5384615384615384 , 0.21071428571428572 , 0.21071428571428572
],
}
residuals = {
    'Perceptron': np.random.randn(100),
    'Logistic': np.random.randn(100),
    'SVC': np.random.randn(100),
}

# Accuracy Bar Chart
x = np.arange(len(scenarios))
width = 0.2

fig, axes = plt.subplots(2, 2, figsize=(12, 8))
ax1 = axes[0, 0]
for i, model in enumerate(models):
    ax1.bar(x + i * width, accuracies[model], width, label=model)

ax1.set_xlabel('Scenarios')
ax1.set_ylabel('Accuracy (%)')
ax1.set_title('Accuracy Comparison')
ax1.set_xticks(x + width)
ax1.set_xticklabels(scenarios)
ax1.legend()
